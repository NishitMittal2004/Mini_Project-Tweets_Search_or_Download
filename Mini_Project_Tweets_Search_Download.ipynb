# %% [markdown]
# <a href="https://colab.research.google.com/github/NishitMittal2004/Mini_Project-Tweets_Search_or_Download/blob/main/Mini_Project_Tweets_Search_Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mini Project - Tweets Search / Download**

# %% [markdown]
# ---
# ## Install Package
# ---

# %%
# !pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.10/dist-packages (4.13.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in /usr/local/lib/python3.10/dist-packages (from tweepy) (2.27.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27.0->tweepy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27.0->tweepy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27.0->tweepy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27.0->tweepy) (3.4)

# %% [markdown]
# ---
# ## Add Credentials
# ---

# %%
access_token = "501682241-ZG1DshytyxUIUY8FXPoH2AXaDG9d5DQlORemfAzU"
access_token_secret = "mxwCYkDjgWG5qWy8ONtVs3j2lxiYSxyberVVa92jmd27z"
consumer_key = "we0Drpnvc1FZNazKkiKoFWlGf"
consumer_secret = "OXRvmJwM6ca9k90XMIMoktSCa5XvjNieqJivcfjbOAlmpO6RhH"

# %%
import os
import tweepy as tw
import pandas as pd

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# ---
# ## Look for tweets and build a dataframe
# ---

# %%
# Collect tweets
results = api.search(q='dengue', count=100)

# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in results], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @f_g_zampieri: @Jopo_dr @GoodishIntent +1 f...
# 1  RT @rabihmgeha: Zika, Chikungunya and Dengue.\...
# 2  ALLENDE, COAHUILA.-\n\nhttps://t.co/95HboRJAYA...
# 3  Friend admitted for dengue in sick room, share...
# 4  RT @BloodDonorsIn: #Mohali\nNeed #Blood Type :...
# 5  방금 사진을 게시했습니다 @뎅기피버 Dengue Fever https://t.co/...
# 6  Lafz dengue Jane ki ijaazat ,tum aankhain Dekh...
# 7  RT @BloodDonorsIn: #Lucknow\nNeed #Blood Type ...
# 8  RT @Sehrish31034866: #Listen_to_SurrahAlrehman...
# 9  From Grafa " Island Pharmaceuticals (ASX:ILA) ...

# %%
data
# Out:
#                                                Tweets
# 0   RT @f_g_zampieri: @Jopo_dr @GoodishIntent +1 f...
# 1   RT @rabihmgeha: Zika, Chikungunya and Dengue.\...
# 2   ALLENDE, COAHUILA.-\n\nhttps://t.co/95HboRJAYA...
# 3   Friend admitted for dengue in sick room, share...
# 4   RT @BloodDonorsIn: #Mohali\nNeed #Blood Type :...
# ..                                                ...
# 95  RT @k86706163: @MDaudkamboh @IamIqraNasir hmm ...
# 96  Salud Colima: Llegada de serotipo 3 puede aume...
# 97  سی ای او ایل ڈبلیو ایم سی کی ہدایات پر نشتر ٹا...
# 98  RT @danaparish: @fitterhappierAJ Wow. I hear f...
# 99  RT @ETimesTV: When Jhalak Dikhhla Jaa 10 parti...
#
# [100 rows x 1 columns]

# %% [markdown]
# Find more at [Tweet Extraction](https://github.com/RodolfoFerro/pandas_twitter/blob/master/01-extracting-data.md)

# %%
data
# Out:
#                                                Tweets
# 0   RT @f_g_zampieri: @Jopo_dr @GoodishIntent +1 f...
# 1   RT @rabihmgeha: Zika, Chikungunya and Dengue.\...
# 2   ALLENDE, COAHUILA.-\n\nhttps://t.co/95HboRJAYA...
# 3   Friend admitted for dengue in sick room, share...
# 4   RT @BloodDonorsIn: #Mohali\nNeed #Blood Type :...
# ..                                                ...
# 95  RT @k86706163: @MDaudkamboh @IamIqraNasir hmm ...
# 96  Salud Colima: Llegada de serotipo 3 puede aume...
# 97  سی ای او ایل ڈبلیو ایم سی کی ہدایات پر نشتر ٹا...
# 98  RT @danaparish: @fitterhappierAJ Wow. I hear f...
# 99  RT @ETimesTV: When Jhalak Dikhhla Jaa 10 parti...
#
# [100 rows x 1 columns]

# %%
df=pd.read_csv('/content/malaria.csv')
df
# Out:
#      Unnamed: 0                       Date             User  \
# 0             0  2018-12-31 12:00:40+00:00   ConversationUS
# 1             1  2018-12-26 15:30:16+00:00        MENTOR_Hq
# 2             2  2018-12-23 15:11:34+00:00   SwachchhasilaB
# 3             3  2018-12-20 15:30:16+00:00        MENTOR_Hq
# 4             4  2018-12-20 08:48:11+00:00   elenagomezdiaz
# ..          ...                        ...              ...
# 572         572  2015-01-06 10:59:53+00:00      MESAmalaria
# 573         573  2015-01-05 16:26:14+00:00       NIAIDBioIT
# 574         574  2015-01-02 08:53:23+00:00        bbbrieger
# 575         575  2015-01-02 05:02:10+00:00  Sergio_Mesquite
# 576         576  2015-01-01 20:22:20+00:00       afya_kenya
#
#                                                  Tweet
# 0    The anopheles #mosquito - by transmitting #mal...
# 1    "Understanding the basis of interactions betwe...
# 2    There was a time when mosquitoes disappeared i...
# 3    "Previous studies in other Sub-Saharan African...
# 4    New #WomenInMalaria contribution to the field ...
# ..                                                 ...
# 572  Clues to why some Anopheles #mosquitoes can tr...
# 573  #Genomes of 16 #Anopheles mosquitoes http://t....
# 574  http://t.co/RfJYpNdA3z Highly evolvable #malar...
# 575  Highly evolvable #malaria vectors: The genomes...
# 576  Highly evolvable malaria vectors: The genomes ...
#
# [577 rows x 4 columns]

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text = " ".join(review for review in df.Tweet)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 106034 words in the combination of all review.

# %%
# Create stopword list:
stopwords = set(STOPWORDS)

# %%
# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(10,10) )
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud

# %%
df["mytext_new"] = df['Tweet'].str.lower().str.replace('[^\w\s]','')


new_df = df.mytext_new.str.split(expand=True).stack().value_counts().reset_index()

new_df.columns = ['Word', 'Frequency']

new_df.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
#          Word  Frequency
# 0     malaria        660
# 1   anopheles        587
# 2         the        388
# 3    mosquito        359
# 4          of        328
# 5          in        240
# 6  mosquitoes        233
# 7           a        190
# 8          to        189
# 9          is        186
